# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../DATA/sammy_face.jpg')

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(img,127,127)
plt.imshow(edges)

# %%
med = np.median(img)

# %%
med
# Out:
# np.float64(64.0)

# %%
#

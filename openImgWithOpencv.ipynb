# %%
import numpy as np

# %%
import cv2

# %%
 import matplotlib.pylab as plt
# %matplotlib inline

# %%
img = cv2.imread('Computer-Vision-with-Python/DATA/car_plate.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 61,  68,  61],
#         [ 58,  65,  58],
#         [ 56,  63,  56],
#         ...,
#         [164, 162, 151],
#         [166, 164, 153],
#         [166, 164, 153]],
#
#        [[ 58,  65,  58],
#         [ 57,  64,  57],
#         [ 56,  63,  56],
#         ...,
#         [164, 162, 151],
#         [165, 163, 152],
#         [165, 163, 152]],
#
#        [[ 59,  66,  59],
#         [ 59,  66,  59],
#         [ 59,  66,  59],
#         ...,
#         [165, 164, 150],
#         [165, 164, 150],
#         [165, 164, 150]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  8,   8,   8],
#         [  0,   0,   0],
#         ...,
#         [ 46,  47,  37],
#         [ 46,  47,  38],
#         [ 46,  47,  38]],
#
#        [[  2,   2,   2],
#         [  0,   0,   0],
#         [  5,   5,   5],
#         ...,
#         [ 46,  47,  37],
#         [ 46,  47,  38],
#         [ 46,  47,  38]],
#
#        [[  3,   3,   3],
#         [  0,   0,   0],
#         [  1,   1,   1],
# ...

# %%
img.shape
# Out:
# (358, 634, 3)

# %%
#matplotliv --> RGB
#cv2 --> BGR

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("Computer-Vision-with-Python/DATA/cartoon_receipt.jpg",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray , cmap='gray')

# %%
fix_img.shape
# Out:
# (358, 634, 3)

# %%
img_resize = cv2.resize(fix_img,(200,200))

# %%
plt.imshow(img_resize)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,-1)

# %%
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

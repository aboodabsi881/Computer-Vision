# %%
import numpy as np
import cv2

import matplotlib.pylab as plt
# %matplotlib inline

# %%
img = cv2.imread('Computer-Vision-with-Python/DATA/dog_backpack.jpg')

# %%
img.shape
# Out:
# (1401, 934, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img)

# %%
fix_color =  cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
fix_color.shape
# Out:
# (1401, 934, 3)

# %%
plt.imshow(fix_color)

# %%
flip_img = cv2.flip(fix_color,0)

# %%
plt.imshow(flip_img)

# %%
cv2.rectangle(fix_color,(200,700),(600,380),(255,0,0),5)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
# ...

# %%
plt.imshow(fix_color)

# %%
ver = np.array([[200, 700],[600, 700],[450, 380]])
ver
# Out:
# array([[200, 700],
#        [600, 700],
#        [450, 380]])

# %%
ver.shape
# Out:
# (3, 2)

# %%
new_ver = ver.reshape(-1,1,2)

# %%
new_ver.shape
# Out:
# (3, 1, 2)

# %%
new_ver
# Out:
# array([[[200, 700]],
#
#        [[600, 700]],
#
#        [[450, 380]]])

# %%
cv2.polylines(fix_color,[new_ver],True,(0,0,255),10)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
# ...

# %%
plt.imshow(fix_color)

# %%
plt.imshow(fix_color)

# %%
cv2.fillPoly(fix_color,[new_ver],(0,0,255))
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
# ...

# %%
plt.imshow(fix_color)

# %%
print(fix_color.shape)
print(fix_color.dtype)
# Out:
# (1401, 934, 3)
# uint8

# %%
img = cv2.imread('Computer-Vision-with-Python/DATA/dog_backpack.png')

def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),50,(0,0,255),10)
cv2.namedWindow(winname="my_drawing")
cv2.setMouseCallback("my_drawing",draw_circle)

while True:
    cv2.imshow('my_drawing',img)
    
    if cv2.waitKey(20) & 0xFF ==27:
        break
cv2.destroyAllWindows()

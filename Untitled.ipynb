# %%
 from datasets import load_dataset
ds = load_dataset("flaviagiammarino/path-vqa")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b86eba53588b> in <module>
# ----> 1 from datasets import load_dataset
#       2 ds = load_dataset("flaviagiammarino/path-vqa")
#
# ~\anaconda3\envs\python-cvcourse\lib\site-packages\datasets\__init__.py in <module>
#      20 __version__ = "2.2.1"
#      21
# ---> 22 import pyarrow
#      23 from packaging import version
#      24
#
# ~\anaconda3\envs\python-cvcourse\lib\site-packages\pyarrow\__init__.py in <module>
#      61 _gc_enabled = _gc.isenabled()
#      62 _gc.disable()
# ---> 63 import pyarrow.lib as _lib
#      64 if _gc_enabled:
#      65     _gc.enable()
#
# ImportError: DLL load failed: The specified procedure could not be found.

# %%
pip install conda-forge numpy pyarrow pandas datasets
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement conda-forge (from versions: none)
# ERROR: No matching distribution found for conda-forge
